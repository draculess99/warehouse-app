# %%
import os
os.getcwd()
# Out:
# 'D:\\Work\\Springboard\\CAPSTONE-Final'

# %%
os.chdir("D:\Work\Springboard\CAPSTONE-Final\TraininData\WORKTRAIN\WalmartBenchmark")

# %%
# ==========================================================
# streamlit_app.py
# Front-end dashboard for your existing Flask forecast API
# Run:
#   1) python app.py
#   2) streamlit run streamlit_app.py
# ==========================================================

import streamlit as st
import requests
import pandas as pd

# ----------------------------------------------------------
# PAGE CONFIG
# ----------------------------------------------------------
st.set_page_config(
    page_title="Warehouse VET / VTO Forecast",
    layout="wide"
)

st.title("Warehouse Workforce Forecast Dashboard")
st.caption("Machine Learning Demand Forecasting + VET / VTO Recommendations")

# ----------------------------------------------------------
# SIDEBAR INPUTS
# ----------------------------------------------------------
st.sidebar.header("Scenario Inputs")

weeks = st.sidebar.slider("Forecast Horizon (Weeks)", 1, 12, 12)

temp = st.sidebar.number_input("Temperature", value=45.0)
fuel = st.sidebar.number_input("Fuel Price", value=3.2)
cpi = st.sidebar.number_input("CPI", value=225.0)
unemployment = st.sidebar.number_input("Unemployment", value=6.5)

scenario_name = st.sidebar.text_input(
    "Scenario Name",
    value="Standard Forecast"
)

request_id = st.sidebar.text_input(
    "Request ID",
    value="REQ001"
)

run_button = st.sidebar.button("Run Forecast")

# ----------------------------------------------------------
# MAIN ACTION
# ----------------------------------------------------------
if run_button:

    # ------------------------------------------------------
    # BUILD PAYLOAD TO SEND TO FLASK API
    # ------------------------------------------------------
    payload = {
        "request_id": request_id,
        "scenario_name": scenario_name,
        "weeks": weeks,

        "inputs": {
            "temperature": [temp] * weeks,
            "fuel_price": [fuel] * weeks,
            "cpi": [cpi] * weeks,
            "unemployment": [unemployment] * weeks,
            "isholiday": [0] * weeks
        }
    }

    # ------------------------------------------------------
    # CALL YOUR FLASK API
    # ------------------------------------------------------
    try:
        response = requests.post(
            "http://127.0.0.1:5000/forecast",
            json=payload,
            timeout=30
        )

        data = response.json()

    except Exception as e:
        st.error("Could not connect to Flask API.")
        st.stop()

    # ------------------------------------------------------
    # SUCCESS HEADER
    # ------------------------------------------------------
    st.success("Forecast Completed")

    # ------------------------------------------------------
    # SUMMARY
    # ------------------------------------------------------
    summary = data["summary"]

    st.subheader("Executive Summary")

    c1, c2, c3, c4 = st.columns(4)

    c1.metric("VET Weeks", summary["vet_weeks"])
    c2.metric("VTO Weeks", summary["vto_weeks"])
    c3.metric("Peak Week", summary["peak_demand_week"])
    c4.metric("Total Cost", f"${summary['total_cost']:,.0f}")

    # ------------------------------------------------------
    # FORECAST TABLE
    # ------------------------------------------------------
    st.subheader("12 Week Forecast Output")

    forecast_df = pd.DataFrame(data["forecast"])

    st.dataframe(
        forecast_df,
        use_container_width=True
    )

    # ------------------------------------------------------
    # CHART
    # ------------------------------------------------------
    st.subheader("Predicted Demand Trend")

    chart_df = forecast_df[["week", "predicted_demand"]]
    chart_df = chart_df.set_index("week")

    st.line_chart(chart_df)

    # ------------------------------------------------------
    # RECOMMENDATIONS
    # ------------------------------------------------------
    st.subheader("Operational Recommendations")

    recommendations = data.get("recommendations", [])

    if len(recommendations) == 0:
        st.info("No recommendations returned.")

    for rec in recommendations:

        txt = rec.lower()

        if "increase staffing" in txt:
            st.warning("⚠️ " + rec)

        elif "vto" in txt:
            st.success("💰 " + rec)

        elif "highest demand" in txt or "peak" in txt:
            st.error("🔥 " + rec)

        elif "cost" in txt or "savings" in txt:
            st.info("📈 " + rec)

        else:
            st.write("• " + rec)

    # ------------------------------------------------------
    # RAW JSON (OPTIONAL)
    # ------------------------------------------------------
    with st.expander("View Raw JSON Response"):
        st.json(data)

else:
    st.info("Use the left sidebar inputs, then click Run Forecast.")
# Out:
# 2026-04-18 06:09:50.181 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.182 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.648
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-18 06:09:50.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.663 Session state does not function when running a script without `streamlit run`
# 2026-04-18 06:09:50.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-18 06:09:50.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
